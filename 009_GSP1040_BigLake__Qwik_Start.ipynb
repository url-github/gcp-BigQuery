# %% [markdown]
# #Przegląd

# %% [markdown]
# ![2023-08-16 16_59_21-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-16 17_35_58-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# gcloud auth list
# gcloud config list project

# %% [markdown]
# customer.csv

# %%
1,Luís,Gonçalves,Embraer - Empresa Brasileira de Aeronáutica S.A.,"Av. Brigadeiro Faria Lima, 2170",São José dos Campos,SP,Brazil,12227-000,+55 (12) 3923-5555,+55 (12) 3923-5566,luisg@embraer.com.br,3
2,Leonie,Köhler,,Theodor-Heuss-Straße 34,Stuttgart,,Germany,70174,+49 0711 2842222,,leonekohler@surfeu.de,5
3,François,Tremblay,,1498 rue Bélanger,Montréal,QC,Canada,H2G 1A7,+1 (514) 721-4711,,ftremblay@gmail.com,3
4,Bjørn,Hansen,,Ullevålsveien 14,Oslo,,Norway,171,+47 22 44 22 22,,bjorn.hansen@yahoo.no,4
5,František,Wichterlová,JetBrains s.r.o.,Klanova 9/506,Prague,,Czech Republic,14700,+420 2 4172 5555,+420 2 4172 5555,frantisekw@jetbrains.com,4
6,Helena,Holý,,Rilská 3174/6,Prague,,Czech Republic,14300,+420 2 4177 0449,,hholy@gmail.com,5
7,Astrid,Gruber,,"Rotenturmstraße 4, 1010 Innere Stadt",Vienne,,Austria,1010,+43 01 5134505,,astrid.gruber@apple.at,5
8,Daan,Peeters,,Grétrystraat 63,Brussels,,Belgium,1000,+32 02 219 03 03,,daan_peeters@apple.be,4
9,Kara,Nielsen,,Sønder Boulevard 51,Copenhagen,,Denmark,1720,+453 3331 9991,,kara.nielsen@jubii.dk,4
10,Eduardo,Martins,Woodstock Discos,"Rua Dr. Falcão Filho, 155",São Paulo,SP,Brazil,01007-010,+55 (11) 3033-5446,+55 (11) 3033-4564,eduardo@woodstock.com.br,4
11,Alexandre,Rocha,Banco do Brasil S.A.,"Av. Paulista, 2022",São Paulo,SP,Brazil,01310-200,+55 (11) 3055-3278,+55 (11) 3055-8131,alero@uol.com.br,5
12,Roberto,Almeida,Riotur,"Praça Pio X, 119",Rio de Janeiro,RJ,Brazil,20040-020,+55 (21) 2271-7000,+55 (21) 2271-7070,roberto.almeida@riotur.gov.br,3

# %% [markdown]
# invoice.csv

# %%
1,2,2009-01-01 00:00:00,Theodor-Heuss-Straße 34,Stuttgart,,Germany,70174,1.98
2,4,2009-01-02 00:00:00,Ullevålsveien 14,Oslo,,Norway,171,3.96
3,8,2009-01-03 00:00:00,Grétrystraat 63,Brussels,,Belgium,1000,5.94
4,14,2009-01-06 00:00:00,8210 111 ST NW,Edmonton,AB,Canada,T6G 2C7,8.91
5,23,2009-01-11 00:00:00,69 Salem Street,Boston,MA,USA,2113,13.86
6,37,2009-01-19 00:00:00,Berger Straße 10,Frankfurt,,Germany,60316,0.99
7,38,2009-02-01 00:00:00,Barbarossastraße 19,Berlin,,Germany,10779,1.98
8,40,2009-02-01 00:00:00,"8, Rue Hanovre",Paris,,France,75002,1.98
9,42,2009-02-02 00:00:00,"9, Place Louis Barthou",Bordeaux,,France,33000,3.96
10,46,2009-02-03 00:00:00,3 Chatham Street,Dublin,Dublin,Ireland,,5.94
11,52,2009-02-06 00:00:00,202 Hoxton Street,London,,United Kingdom,N1 5LH,8.91
12,2,2009-02-11 00:00:00,Theodor-Heuss-Straße 34,Stuttgart,,Germany,70174,13.86
13,16,2009-02-19 00:00:00,1600 Amphitheatre Parkway,Mountain View,CA,USA,94043-1351,0.99
14,17,2009-03-04 00:00:00,1 Microsoft Way,Redmond,WA,USA,98052-8300,1.98
15,19,2009-03-04 00:00:00,1 Infinite Loop,Cupertino,CA,USA,95014,1.98
16,21,2009-03-05 00:00:00,801 W 4th Street,Reno,NV,USA,89503,3.96
17,25,2009-03-06 00:00:00,319 N. Frances Street,Madison,WI,USA,53703,5.94
18,31,2009-03-09 00:00:00,194A Chain Lake Drive,Halifax,NS,Canada,B3S 1C5,8.91
19,40,2009-03-14 00:00:00,"8, Rue Hanovre",Paris,,France,75002,13.86
20,54,2009-03-22 00:00:00,110 Raeburn Pl,Edinburgh ,,United Kingdom,EH4 1HH,0.99
21,55,2009-04-04 00:00:00,421 Bourke Street,Sidney,NSW,Australia,2010,1.98

# %% [markdown]
# #Zadanie 1. Utwórz zasób połączenia

# %% [markdown]
# ![2023-08-17 09_04_26-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_40_06-External data source – BigQuery – qwiklabs-gcp-01-1a8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# https://cloud.google.com/bigquery/docs/working-with-connections

# %% [markdown]
# ![2023-08-17 10_28_58-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# Service account id

bqcx-469280117311-t29b@gcp-sa-bigquery-condel.iam.gserviceaccount.com

# %% [markdown]
# #Zadanie 2. Skonfiguruj dostęp do jeziora danych Cloud Storage

# %% [markdown]
# ![2023-08-17 10_31_41-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_44_08-IAM – IAM & Admin – qwiklabs-gcp-01-1a8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# #Zadanie 3. Utwórz tabelę BigLake

# %% [markdown]
# ![2023-08-17 10_38_53-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_46_00-Create dataset – BigQuery – qwiklabs-gcp-01-1a8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 10_57_13-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 11_00_52-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
[
{
    "name": "customer_id",
    "type": "INTEGER",
    "mode": "REQUIRED"
  },
  {
    "name": "first_name",
    "type": "STRING",
    "mode": "REQUIRED"
  },
  {
    "name": "last_name",
    "type": "STRING",
    "mode": "REQUIRED"
  },
  {
    "name": "company",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "address",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "city",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "state",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "country",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "postal_code",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "phone",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "fax",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "email",
    "type": "STRING",
    "mode": "REQUIRED"
  },
  {
    "name": "support_rep_id",
    "type": "INTEGER",
    "mode": "NULLABLE"
  }
]

# %% [markdown]
# ![2023-08-17 12_49_55-Create table – BigQuery – qwiklabs-gcp-01-1a8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 11_28_12-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# #Zadanie 4. Zapytanie w tabeli BigLake za pomocą BigQuery

# %% [markdown]
# ![2023-08-17 11_36_30-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# %%bigquery
#
# SELECT * FROM `qwiklabs-gcp-01-1a810c855897.demo_dataset.biglake_table`

# %% [markdown]
# ![2023-08-17 11_36_30-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_52_37-BigQuery – qwiklabs-gcp-01-1a8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# #Zadanie 5. Skonfiguruj zasady kontroli dostępu

# %% [markdown]
# ![2023-08-17 12_00_48-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# https://cloud.google.com/bigquery/docs/best-practices-policy-tags
#
# https://cloud.google.com/bigquery/docs/managing-row-level-security

# %% [markdown]
# ![2023-08-17 12_03_38-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_56_24-Edit Schema – BigQuery – qwiklabs-gcp-01-1a8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_58_01-biglake-ta…omy-40kb4 – Policy tag taxonomy – BigQuery – qwiklabs-gcp-01-1a8… – G.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_05_14-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_06_08-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# %%bigquery
#
# SELECT * FROM `qwiklabs-gcp-01-1a810c855897.demo_dataset.biglake_table`

# %% [markdown]
# ![2023-08-17 12_12_13-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_12_45-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# %%bigquery
#
# SELECT *  EXCEPT(address, phone, postal_code)
# FROM `qwiklabs-gcp-01-1a810c855897.demo_dataset.biglake_table`

# %% [markdown]
# #Zadanie 6. Uaktualnij tabele zewnętrzne do tabel BigLake

# %% [markdown]
# ![2023-08-17 12_15_10-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# https://cloud.google.com/bigquery/docs/reference/bq-cli-reference#bq_update
#
# https://cloud.google.com/bigquery/docs/reference/bq-cli-reference#bq_mkdef

# %%
[
{
    "name": "invoice_id",
    "type": "INTEGER",
    "mode": "REQUIRED"
  },
  {
    "name": "customer_id",
    "type": "INTEGER",
    "mode": "REQUIRED"
  },
  {
    "name": "invoice_date",
    "type": "TIMESTAMP",
    "mode": "REQUIRED"
  },
  {
    "name": "billing_address",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "billing_city",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "billing_state",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "billing_country",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "billing_postal_code",
    "type": "STRING",
    "mode": "NULLABLE"
  },
  {
    "name": "total",
    "type": "NUMERIC",
    "mode": "REQUIRED"
  }
]

# %% [markdown]
# ![2023-08-17 13_03_07-Create table – BigQuery – qwiklabs-gcp-01-1a8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_20_15-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# https://cloud.google.com/bigquery/docs/external-table-definition#table-definition

# %%
export PROJECT_ID=$(gcloud config get-value project)
bq mkdef \
--autodetect \
--connection_id=$PROJECT_ID.US.my-connection \
--source_format=CSV \
"gs://$PROJECT_ID/invoice.csv" > /tmp/tabledef.json

# %% [markdown]
# ![2023-08-17 13_08_34-BigQuery – qwiklabs-gcp-01-1a8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_22_09-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
cat /tmp/tabledef.json

# %% [markdown]
# ![2023-08-17 13_04_26-BigQuery – qwiklabs-gcp-01-1a8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 12_22_44-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
bq show --schema --format=prettyjson  demo_dataset.external_table > /tmp/schema

# %% [markdown]
# ![2023-08-17 12_23_37-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
bq update --external_table_definition=/tmp/tabledef.json --schema=/tmp/schema demo_dataset.external_table

# %% [markdown]
# ![2023-08-17 12_24_42-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-17 13_11_10-BigQuery – qwiklabs-gcp-01-1a8… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ===================================
#
# Nieoczekiwany wyjątek w operacji aktualizacji: napotkałeś błąd w interfejsie wiersza polecenia BigQuery. Zgłoś błąd w naszym publicznym narzędziu do śledzenia problemów:
# https://issuetracker.google.com/issues/new?component=187149&template=0
# Dołącz krótki opis kroków, które doprowadziły do tego problemu, a także wiersze, które można upublicznić na podstawie następujących informacji:

# %% [markdown]
# ![2023-08-17 12_27_24-BigLake_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# https://cloud.google.com/bigquery/docs/biglake-intro
#
# https://cloud.google.com/bigquery/docs/query-cloud-storage-using-biglake#set_up_access_to_a_cloud_storage_data_lake
#
#
# https://cloud.google.com/bigquery/docs/query-cloud-storage-using-biglake#query_a_biglake_table_using_connectors
