# %% [markdown]
# #Qwiklabs - Przegląd

# %% [markdown]
# ![2023-10-08 19_56_42-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# #Zadanie 1. Stwórz swój zbiór danych

# %% [markdown]
# ![2023-10-08 20_04_35-Using BigQuery ML to Predict Penguin Weight _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# #Zadanie 2. Stwórz swój model

# %% [markdown]
# ![2023-10-08 20_05_54-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# ```
# CREATE OR REPLACE MODEL `bqml_tutorial.penguins_model`
# OPTIONS
#   (model_type='linear_reg',
#   input_label_cols=['body_mass_g']) AS
# SELECT
#   *
# FROM
#   `bigquery-public-data.ml_datasets.penguins`
# WHERE
#   body_mass_g IS NOT NULL
#
#   ```

# %% [markdown]
# ![2023-10-08 20_07_55-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-create

# %% [markdown]
# ![2023-10-08 20_23_47-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %%
# %%bigquery
#
# CREATE OR REPLACE MODEL `bqml_tutorial.penguins_model`
# OPTIONS
#   (model_type='linear_reg',
#   input_label_cols=['body_mass_g']) AS
# SELECT
#   *
# FROM
#   `bigquery-public-data.ml_datasets.penguins`
# WHERE
#   body_mass_g IS NOT NULL

# %% [markdown]
# ![2023-10-08 20_24_18-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# #Zadanie 3. Uzyskaj statystyki treningowe (Opcjonalnie)

# %% [markdown]
# ![2023-10-08 20_29_24-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-train

# %%
# %%bigquery
#
# SELECT
#   *
# FROM
#   ML.TRAINING_INFO(MODEL `qwiklabs-gcp-01-13f669c4cee8.bqml_tutorial.penguins_model`)

# %% [markdown]
# ![2023-10-09 14_55_03-BigQuery – qwiklabs-gcp-01-13f… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-10-08 20_43_11-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# Mean Squared Error (MSE)

# %% [markdown]
# ![2023-10-08 20_45_25-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# AUTO_STRATEGY: To jest ustawienie domyślne.

# %% [markdown]
# https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-create-glm#optimize_strategy
#
# https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-create-glm

# %% [markdown]
# ![2023-10-09 10_04_45-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-train

# %% [markdown]
# #Zadanie 4. Oceń swój model

# %% [markdown]
# ![2023-10-09 10_06_49-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# ```
# SELECT
#   *
# FROM
#   ML.EVALUATE(MODEL `bqml_tutorial.penguins_model`,
#     (
#     SELECT
#       *
#     FROM
#       `bigquery-public-data.ml_datasets.penguins`
#     WHERE
#       body_mass_g IS NOT NULL))
# ```

# %% [markdown]
# ![2023-10-09 10_11_02-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# ```
# #standardSQL
# SELECT
#   *
# FROM
#   ML.EVALUATE(MODEL `bqml_tutorial.penguins_model`)
#
# ```

# %% [markdown]
# ![2023-10-09 10_46_36-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %%
# %%bigquery
#
# SELECT
#   *
# FROM
#   ML.EVALUATE(MODEL `bqml_tutorial.penguins_model`,
#     (
#     SELECT
#       *
#     FROM
#       `bigquery-public-data.ml_datasets.penguins`
#     WHERE
#       body_mass_g IS NOT NULL))

# %% [markdown]
# ![2023-10-09 12_37_21-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# #Zadanie 5. Wykorzystaj swój model do przewidywania wyników

# %% [markdown]
# ![2023-10-09 12_41_03-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# ```
# SELECT
#   *
# FROM
#   ML.PREDICT(MODEL `bqml_tutorial.penguins_model`,
#     (
#     SELECT
#       *
#     FROM
#       `bigquery-public-data.ml_datasets.penguins`
#     WHERE
#       body_mass_g IS NOT NULL
#       AND island = "Biscoe"))
#
# ```

# %% [markdown]
# ![2023-10-09 13_19_15-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %%
# %%bigquery
#
#   SELECT
#     *
#   FROM
#     ML.PREDICT(MODEL `bqml_tutorial.penguins_model`,
#       (
#       SELECT
#         *
#       FROM
#         `bigquery-public-data.ml_datasets.penguins`
#       WHERE
#         body_mass_g IS NOT NULL
#         AND island = "Biscoe"))

# %% [markdown]
# ![2023-10-09 13_20_57-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-10-09 14_57_43-BigQuery – qwiklabs-gcp-01-13f… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# #Zadanie 6. Wyjaśnij wyniki przewidywań za pomocą możliwych do wyjaśnienia metod AI

# %% [markdown]
# ![2023-10-09 13_29_12-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-explain-predict
#
# https://cloud.google.com/bigquery/docs/xai-overview#explainable_ai_offerings_in_bigquery_ml

# %% [markdown]
# ```
# SELECT
#   *
# FROM
#   ML.EXPLAIN_PREDICT(MODEL `bqml_tutorial.penguins_model`,
#     (
#     SELECT
#       *
#     FROM
#       `bigquery-public-data.ml_datasets.penguins`
#     WHERE
#       body_mass_g IS NOT NULL
#       AND island = "Biscoe"),
#     STRUCT(3 as top_k_features))
#   ```

# %% [markdown]
# ![2023-10-09 13_36_27-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %%
# %%bigquery
#
# SELECT
# *
# FROM
# ML.EXPLAIN_PREDICT(MODEL `bqml_tutorial.penguins_model`,
#   (
#   SELECT
#     *
#   FROM
#     `bigquery-public-data.ml_datasets.penguins`
#   WHERE
#     body_mass_g IS NOT NULL
#     AND island = "Biscoe"),
#   STRUCT(3 as top_k_features))

# %% [markdown]
# ![2023-10-09 14_59_06-BigQuery – qwiklabs-gcp-01-13f… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-10-09 13_36_59-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-explain-predict#mlexplain_predict_output

# %% [markdown]
# #Zadanie 7. Globalnie wyjaśnij swój model (opcjonalnie)

# %% [markdown]
# ![2023-10-09 13_45_00-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %%
# %%bigquery
#
# CREATE OR REPLACE MODEL bqml_tutorial.penguins_model
# OPTIONS
#   (model_type='linear_reg',
#   input_label_cols=['body_mass_g'],
#   enable_global_explain=TRUE) AS
# SELECT
#   *
# FROM
#   `bigquery-public-data.ml_datasets.penguins`
# WHERE
#   body_mass_g IS NOT NULL

# %% [markdown]
# ![2023-10-09 13_47_08-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# ```
# SELECT
#   *
# FROM
#   ML.GLOBAL_EXPLAIN(MODEL `bqml_tutorial.penguins_model`)
# ```

# %% [markdown]
# ![2023-10-09 13_49_21-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %%
# %%bigquery
#
# SELECT
# *
# FROM
# ML.GLOBAL_EXPLAIN(MODEL `bqml_tutorial.penguins_model`)

# %% [markdown]
# ![2023-10-09 15_00_41-BigQuery – qwiklabs-gcp-01-13f… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-10-09 13_53_58-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# #Zadanie 8. Posprzątaj

# %% [markdown]
# ![2023-10-09 14_04_42-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-10-09 14_08_53-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-10-09 14_10_24-Używanie BigQuery ML do przewidywania wagi pingwina _ Zwiększenie umiejętności w.png](data:image/png;base64,...)

# %% [markdown]
# #Dokumentacja BQ - Przegląd
#
# * Use BigQuery ML to predict penguin weigh

# %% [markdown]
# * https://cloud.google.com/bigquery/docs/e2e-journey
#
# * https://cloud.google.com/bigquery/docs/linear-regression-tutorial
#
# * [tabela BQ](https://console.cloud.google.com/bigquery?p=bigquery-public-data&d=ml_datasets&t=penguins&page=table&_ga=2.94759004.1744870421.1692803387-633182317.1692803387&project=empik-mobile-app&ws=!1m5!1m4!4m3!1sbigquery-public-data!2sml_datasets!3spenguins&authuser=2)
#
# * https://cloud.google.com/bigquery/docs/reference/standard-sql/bigqueryml-syntax-create-glm

# %% [markdown]
# ##Cele

# %% [markdown]
# ![2023-08-23 18_40_29-Użyj BigQuery ML, aby przewidzieć wagę pingwina _ Chmura Google.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-23 19_02_23-BigQuery – Empik Mobile App v2 – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-08-24 17_21_54-Użyj BigQuery ML, aby przewidzieć wagę pingwina _ Chmura Google.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-10-09 10_17_00-BigQuery – Empik Mobile App v2 – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ##Stwórz swój model (Krok 1)
#
# ## CREATE OR REPLACE MODEL

# %%
# %%bigquery
#
# CREATE OR REPLACE MODEL `prj-ecom-p-ad-server-1077.pmackowka_us.model_0061`
# OPTIONS
#   (model_type='linear_reg',
#   input_label_cols=['body_mass_g']) AS
# SELECT
#   *
# FROM
#   `bigquery-public-data.ml_datasets.penguins`
# WHERE
#   body_mass_g IS NOT NULL

# %%
# Tworzy i trenuje nowy model w określonym zestawie danych
# CREATE MODEL | CREATE MODEL IF NOT EXISTS | CREATE OR REPLACE MODEL
CREATE OR REPLACE MODEL `prj-ecom-p-ad-server-1077.pmackowka_us.model_0063`
OPTIONS

  # Typ modelu
  # 'LINEAR_REG' | 'LOGISTIC_REG'
  (model_type='LINEAR_REG',

  INPUT_LABEL_COLS=['body_mass_g'],

  # Strategia uczenia modeli regresji liniowej
  # 'AUTO_STRATEGY' | 'BATCH_GRADIENT_DESCENT' | 'NORMAL_EQUATION'
  optimize_strategy = 'BATCH_GRADIENT_DESCENT',

  # Regularyzacja, Wartość domyślna to 0.
  L1_REG = 1,
  # Regularyzacja, Wartość domyślna to 0.
  L2_REG = 1,

  # Maksymalna liczba iteracji lub kroków szkoleniowych, Wartość domyślna to 20.
  MAX_ITERATIONS = 50,

  # Strategia określania szybkości uczenia się podczas treningu. Wartość domyślna to 'LINE_SEARCH'.
  # 'LINE_SEARCH' | 'CONSTANT'
  LEARN_RATE_STRATEGY = 'LINE_SEARCH'



  ) AS
SELECT
  *
FROM
  `bigquery-public-data.ml_datasets.penguins`
WHERE
  body_mass_g IS NOT NULL

# %% [markdown]
# ##Uzyskaj statystyki dotyczące treningu (Krok 2)
# * Aby zobaczyć wyniki uczenia modelu możesz skorzystać z `ML.TRAINING_INFO` funkcji lub obejrzeć statystyki w konsoli Google Cloud. W tym samouczku użyjesz konsoli Google Cloud.
# * Strata to kara za złe przewidywanie — liczba wskazująca, jak złe były przewidywania modelu w pojedynczym przykładzie. Jeśli przewidywania modelu są doskonałe, strata wynosi zero; w przeciwnym razie strata jest większa. Celem uczenia modelu jest znalezienie zestawu wag i odchyleń, które mają średnio niską stratę we wszystkich przykładach.

# %% [markdown]
# ![2023-08-24 17_41_22-pmackowka_ml_us – BigQuery – Empik GA360 – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ##Oceń swój model (Krok 3)
#
# ##ML.EVALUATE

# %%
# %%bigquery
#
# SELECT
#   *
# FROM
#   ML.EVALUATE(MODEL `prj-ecom-p-ad-server-1077.pmackowka_us.model_0061`,
#     (
#     SELECT
#       *
#     FROM
#       `bigquery-public-data.ml_datasets.penguins`
#     WHERE
#       body_mass_g IS NOT NULL))

# %% [markdown]
# ![2023-08-24 17_54_57-pmackowka_ml_us – BigQuery – Empik GA360 – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# * Można także dzwonić `ML.EVALUATE` bez podawania danych wejściowych

# %%
# %%bigquery
#
# SELECT
#   *
# FROM
#   ML.EVALUATE(MODEL `prj-ecom-p-ad-server-1077.pmackowka_us.model_006`)

# %% [markdown]
# ![2023-08-24 17_54_57-pmackowka_ml_us – BigQuery – Empik GA360 – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# * Możesz także użyć konsoli Google Cloud, aby wyświetlić wskaźniki oceny obliczone podczas szkolenia. Wyniki powinny wyglądać następująco:

# %% [markdown]
# ![2023-08-24 17_32_52-pmackowka_ml_us – BigQuery – Empik GA360 – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# *  Wynik R2 jest miarą statystyczną, która określa, czy przewidywania regresji liniowej są zbliżone do rzeczywistych danych . Wartość 0 wskazuje, że model nie wyjaśnia żadnej zmienności danych odpowiedzi wokół średniej. 1 wskazuje, że model wyjaśnia całą zmienność danych odpowiedzi wokół średniej.

# %% [markdown]
# ##Użyj swojego modelu do przewidywania wyników (Krok 4)
#
# ##ML.PREDICT

# %% [markdown]
# * kolumna `predicted_body_mass_g` jest generowana przez `ML.PREDICT` funkcję

# %%
# %%bigquery
#
# SELECT
#   *
# FROM
#   ML.PREDICT(MODEL `prj-ecom-p-ad-server-1077.pmackowka_us.model_0061`,
#     (
#     SELECT
#       *
#     FROM
#       `bigquery-public-data.ml_datasets.penguins`
#     WHERE
#       body_mass_g IS NOT NULL
#       AND island = "Biscoe"))

# %% [markdown]
# ![2023-08-24 19_07_51-pmackowka_ml_us – BigQuery – Empik GA360 – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ##Wyjaśnij wyniki przewidywań za pomocą możliwych do wyjaśnienia metod AI (Krok 5)
#
# ##ML.EXPLAIN_PREDICT
#
# * Aby zrozumieć, dlaczego Twój model generuje takie wyniki przewidywań, możesz użyć tej `ML.EXPLAIN_PREDICT` funkcji.
# * ML.EXPLAIN_PREDICT zwraca wyniki prognozy z dodatkowymi kolumnami wyjaśniającymi te wyniki
#
# * https://cloud.google.com/bigquery/docs/xai-overview#explainable_ai_offerings_in_bigquery_ml

# %%
# %%bigquery
#
# SELECT
# * except(species, island, culmen_length_mm, culmen_depth_mm, flipper_length_mm, sex)
# FROM
# ML.EXPLAIN_PREDICT(MODEL `prj-ecom-p-ad-server-1077.pmackowka_us.model_0061`,
#   (
#   SELECT
#     *
#   FROM
#     `bigquery-public-data.ml_datasets.penguins`
#   WHERE
#     body_mass_g IS NOT NULL
#     AND island = "Biscoe"),
#   STRUCT(3 as top_k_features)
#   )

# %% [markdown]
# ![2023-08-24 19_44_38-pmackowka_ml_us – BigQuery – Empik GA360 – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ##Globalnie wyjaśnij swój model (Krok 6)
#
# ##ML.GLOBAL_EXPLAIN
#
# * Aby móc z niej skorzystać `ML.GLOBAL_EXPLAIN` należy przeszkolić model z opcją `ENABLE_GLOBAL_EXPLAIN=TRUE`

# %%
# %%bigquery
#
# CREATE OR REPLACE MODEL `prj-ecom-p-ad-server-1077.pmackowka_us.model_0062`
# OPTIONS
#   (model_type='linear_reg',
#   input_label_cols=['body_mass_g'],
#   enable_global_explain=TRUE) AS
# SELECT
#   *
# FROM
#   `bigquery-public-data.ml_datasets.penguins`
# WHERE
#   body_mass_g IS NOT NULL

# %% [markdown]
# * Explainable AI pozwala objaśnić model i generowane przez niego prognozy. Poniżej znajdują się cechy o najwyższych wynikach ważności dla całego Twojego modelu. Aby uzyskać możliwe do wyjaśnienia prognozy dla poszczególnych przykładów, uruchom ML.EXPLAIN_PREDICT lub ML.EXPLAIN_FORECAST.

# %% [markdown]
# ![2023-08-25 20_05_03-BigQuery – prj-ecom-p-ad-server – Google Cloud Console.png](data:image/png;base64,...)

# %%
# %%bigquery
#
# SELECT
#   *
# FROM
#   ML.GLOBAL_EXPLAIN(MODEL `prj-ecom-p-ad-server-1077.pmackowka_us.model_0062`)

# %% [markdown]
# ![2023-08-25 20_10_12-BigQuery – prj-ecom-p-ad-server – Google Cloud Console.png](data:image/png;base64,...)
